# %%
import pandas as pd

# %%
pip install --trusted-host pypi.org --trusted-host files.pythonhosted.org jupyterlab
# Out:
# Collecting jupyterlab
#   Downloading jupyterlab-3.4.2-py3-none-any.whl (8.8 MB)
#      ---------------------------------------- 8.8/8.8 MB 12.2 MB/s eta 0:00:00
# Requirement already satisfied: tornado>=6.1.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab) (6.1)
# Requirement already satisfied: jinja2>=2.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: jupyter-core in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab) (4.10.0)
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.13.0-py3-none-any.whl (53 kB)
#      ---------------------------------------- 53.5/53.5 KB ? eta 0:00:00
# Requirement already satisfied: ipython in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab) (8.2.0)
# Requirement already satisfied: packaging in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab) (21.3)
# Collecting nbclassic~=0.2
#   Downloading nbclassic-0.3.7-py3-none-any.whl (13 kB)
# Collecting jupyter-server~=1.16
#   Downloading jupyter_server-1.17.0-py3-none-any.whl (342 kB)
#      ------------------------------------- 342.8/342.8 KB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: pywinpty in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (2.0.5)
# Requirement already satisfied: pyzmq>=17 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (22.3.0)
# Collecting websocket-client
#   Downloading websocket_client-1.3.2-py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.3/54.3 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: argon2-cffi in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (0.13.3)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (6.5.0)
# Requirement already satisfied: prometheus-client in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (0.14.1)
# Requirement already satisfied: traitlets>=5.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (5.1.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (7.3.1)
# Requirement already satisfied: nbformat>=5.2.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (5.4.0)
# Requirement already satisfied: Send2Trash in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (1.8.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-server~=1.16->jupyterlab) (3.5.0)
# Requirement already satisfied: pywin32>=1.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-core->jupyterlab) (304)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.5.1)
# Collecting json5
#   Downloading json5-0.9.8.tar.gz (22 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.27.1)
# Requirement already satisfied: importlib-metadata>=3.6 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.11.3)
# Collecting babel
#   Downloading Babel-2.10.1-py3-none-any.whl (9.5 MB)
#      ---------------------------------------- 9.5/9.5 MB 10.7 MB/s eta 0:00:00
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.1.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: notebook<7 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbclassic~=0.2->jupyterlab) (6.4.11)
# Requirement already satisfied: colorama in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (3.0.29)
# Requirement already satisfied: jedi>=0.16 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.18.1)
# Requirement already satisfied: decorator in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: stack-data in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (2.11.2)
# Requirement already satisfied: pickleshare in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: backcall in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipython->jupyterlab) (62.1.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from packaging->jupyterlab) (3.0.9)
# Requirement already satisfied: sniffio>=1.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab) (1.2.0)
# Requirement already satisfied: idna>=2.8 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab) (3.3)
# Collecting zipp>=0.5
#   Using cached zipp-3.8.0-py3-none-any.whl (5.4 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (21.4.0)
# Requirement already satisfied: nest-asyncio>=1.5.4 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (2.8.2)
# Requirement already satisfied: entrypoints in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (0.4)
# Requirement already satisfied: bleach in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (5.0.0)
# Requirement already satisfied: jupyterlab-pygments in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.2.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.8.4)
# Requirement already satisfied: defusedxml in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.7.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.6.3)
# Requirement already satisfied: beautifulsoup4 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (4.11.1)
# Requirement already satisfied: tinycss2 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (1.1.1)
# Requirement already satisfied: fastjsonschema in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from nbformat>=5.2.0->jupyter-server~=1.16->jupyterlab) (2.15.3)
# Requirement already satisfied: ipython-genutils in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab) (0.2.0)
# Requirement already satisfied: ipykernel in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from notebook<7->nbclassic~=0.2->jupyterlab) (6.13.0)
# Requirement already satisfied: wcwidth in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: argon2-cffi-bindings in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from argon2-cffi->jupyter-server~=1.16->jupyterlab) (21.2.0)
# Requirement already satisfied: pytz>=2015.7 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from babel->jupyterlab-server~=2.10->jupyterlab) (2022.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2021.10.8)
# Requirement already satisfied: pure-eval in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: executing in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from stack-data->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: asttokens in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from stack-data->ipython->jupyterlab) (2.0.5)
# Requirement already satisfied: six>=1.5 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->jupyter-server~=1.16->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server~=1.16->jupyterlab) (0.5.1)
# Requirement already satisfied: psutil in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab) (5.9.0)
# Requirement already satisfied: debugpy>=1.0 in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from ipykernel->notebook<7->nbclassic~=0.2->jupyterlab) (1.6.0)
# Requirement already satisfied: pycparser in c:\www\linuxtips\python-week-2022\cursopythonyt\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server~=1.16->jupyterlab) (2.21)
# Using legacy 'setup.py install' for json5, since package 'wheel' is not installed.
# Installing collected packages: json5, zipp, websocket-client, babel, jupyter-server, notebook-shim, jupyterlab-server, nbclassic, jupyterlab
#   Running setup.py install for json5: started
#   Running setup.py install for json5: finished with status 'done'
# Successfully installed babel-2.10.1 json5-0.9.8 jupyter-server-1.17.0 jupyterlab-3.4.2 jupyterlab-server-2.13.0 nbclassic-0.3.7 notebook-shim-0.1.0 websocket-client-1.3.2 zipp-3.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
data = pd.read_csv("openbeerdb_csv/beers.csv", low_memory=False, usecols=["name","abv"], nrows=100)

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'abv',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'get',
#  'groupby',
#  'gt',
#  'head',
#  'hist',
#  'iat',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'mul',
#  'multiply',
#  'name',
#  'ndim',
#  'ne',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'pow',
#  'prod',
#  'product',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'squeeze',
#  'stack',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tail',
#  'take',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
data
# Out:
#                         name  abv
# 0                Hocus Pocus  4.5
# 1          Grimbergen Blonde  6.7
# 2     Widdershins Barleywine  9.1
# 3                    Lucifer  8.5
# 4                     Bitter    4
# ...                      ...  ...
# 5856           Honey Rye Ale    0
# 5857              Strawberry    0
# 5858             Satsuma Wit    0
# 5859               Abhi beer    0
# 5860                    Ambr    0
#
# [5861 rows x 2 columns]

# %%
data["abv"] = data["abv"].astype(float)

# %%
data.plot(kind="barh", x="name", y="abv", figsize=(20, 20))
# Out:
# <AxesSubplot:ylabel='name'>

# %%
data = pd.read_sql_table("beer", "sqlite:///beerlog.db", columns=["name","rate"])

# %%
data.plot(kind="barh", y="rate", x="name", figsize=(20, 10))
# Out:
# <AxesSubplot:ylabel='name'>

# %%
# scraper = pd.read_html("https://en.wikipedia.org/wiki/List_of_countries_by_beer_consumption_per_capita", attrs={"class":"wikitable"})

# %%
# table = scraper[0]

# %%
# table["Country"] = table["Country"].apply(lambda c: c.upper().replace("*", ""))

# %%
# table = table[["Country", "Consumptionper capital[1](litres per year)"]]

# %%
# table.plot(kind="barh", y=1, x=0, figsize=(20, 20))
